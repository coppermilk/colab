# %% [markdown]
# <a href="https://colab.research.google.com/github/coppermilk/colab/blob/main/or_nor_and_nand_xor_xnor_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # OR

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[1]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

or_history = model.fit(X, y, batch_size=1, epochs=200)
print(model.predict(X))

plt.plot(or_history.history['loss'], label='OR')
plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6766
# Epoch 2/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5839
# Epoch 3/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5261
# Epoch 4/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4866
# Epoch 5/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4569
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4335
# Epoch 7/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4136
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3962
# Epoch 9/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3788
# Epoch 10/200
# ...

# %% [markdown]
# # NOR

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[1],[0],[0],[0]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

nor_history = model.fit(X, y, batch_size=1, epochs=200)
print(model.predict(X))

plt.plot(nor_history.history['loss'], label='NOR')
plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8504
# Epoch 2/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7018
# Epoch 3/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6192
# Epoch 4/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5685
# Epoch 5/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5323
# Epoch 6/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5020
# Epoch 7/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4805
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4606
# Epoch 9/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4429
# Epoch 10/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4261
# Epoch 11/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4097
# Epoch 12/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3944
# ...

# %% [markdown]
# # AND

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[0],[0],[1]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

and_history = model.fit(X, y, batch_size=1, epochs=200)
print(model.predict(X))
plt.plot(and_history.history['loss'], 
         label='AND')

plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7626
# Epoch 2/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6698
# Epoch 3/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6109
# Epoch 4/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5725
# Epoch 5/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5477
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5311
# Epoch 7/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5066
# Epoch 8/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4883
# Epoch 9/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4748
# Epoch 10/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4564
# Epoch 11/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4393
# Epoch 12/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4210
# ...

# %% [markdown]
# # NAND

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[1],[1],[1],[0]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

nand_history = model.fit(X, y, batch_size=1, epochs=200)
print(model.predict(X))
plt.plot(nand_history.history['loss'], 
         label='NAND')

plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7742
# Epoch 2/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6763
# Epoch 3/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6261
# Epoch 4/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5952
# Epoch 5/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5697
# Epoch 6/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5432
# Epoch 7/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5246
# Epoch 8/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5063
# Epoch 9/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4859
# Epoch 10/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4718
# Epoch 11/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4530
# Epoch 12/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4408
# ...

# %% [markdown]
# # XOR

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

xor_history = model.fit(X, y, batch_size=1, epochs=200)
print(model.predict(X))
plt.plot(xor_history.history['loss'], 
         label='XOR')

plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8309
# Epoch 2/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8144
# Epoch 3/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7995
# Epoch 4/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7853
# Epoch 5/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7729
# Epoch 6/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7697
# Epoch 7/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7636
# Epoch 8/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7573
# Epoch 9/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7531
# Epoch 10/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7480
# Epoch 11/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7379
# Epoch 12/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7403
# ...

# %% [markdown]
# # XNOR

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[1],[0],[0],[1]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)

xnor_history = model.fit(X, y, batch_size=1, epochs=200)
print(model.predict(X))
plt.plot(xnor_history.history['loss'], 
         label='XNOR')

plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7909
# Epoch 2/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7745
# Epoch 3/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7719
# Epoch 4/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7670
# Epoch 5/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7634
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7559
# Epoch 7/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7563
# Epoch 8/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7493
# Epoch 9/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7528
# Epoch 10/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7502
# Epoch 11/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7464
# Epoch 12/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7439
# ...

# %%
plt.plot(or_history.history['loss'], label='OR')
plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()

plt.plot(nor_history.history['loss'], label='NOR')
plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()

plt.plot(and_history.history['loss'], label='AND')
plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()

plt.plot(nand_history.history['loss'], label='NAND')
plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()

plt.plot(xor_history.history['loss'], label='XOR')
plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()

plt.plot(xnor_history.history['loss'], label='XNOR')
plt.xlabel('Epoch')
plt.ylabel('Error rate')
plt.legend()
plt.show()
